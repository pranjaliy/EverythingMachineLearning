# %% [markdown]
# ***
# ### How is statistical insight assessed?
# 1. Hypothesis testing is used to assess statistical significance.
# 2. Null hypothesis is designed to say that it insight is not significant and alternate says its is significant.
# 3. p-value is calculated, it tells you how likely your data satisfies the null hypothesis, 5% of the time you will find data where the null hypothesis is true.

# %% [markdown]
# ***
# ### p-value
#
# 1. p value or the probability value, tells how likely your data could have occurred under a null hypothesis
# 2. The p-value is a proportion: if your p-value is 0.05, that means that 5% of the time you would see a test statistic(t of test) at least as extreme as the one you found if the null hypothesis was true.
# 3. If we get enough evidence to reject null hypothesis, it means we wont find data even 5% of the time which satisfies null hypothesis. if we reduce p to 0.01, it means 1% of the time you would see a test statistic at least as extreme as the one you found if the null hypothesis was true.
# >If the mice live equally long on either diet, then the test statistic from your t-test will closely match the test statistic from the null hypothesis (that there is no difference between groups), and the resulting p-value will be close to 1. It likely won’t reach exactly 1, because in real life the groups will probably not be perfectly equal. If, however, there is an average difference in longevity between the two groups, then your test statistic will move further away from the values predicted by the null hypothesis, and the p-value will get smaller. The p-value will never reach zero, because there’s always a possibility, even if extremely unlikely, that the patterns in your data occurred by chance.
#
# 4. Statistical significance is another way of saying that the p-value of a statistical test is small enough to reject the null hypothesis of the test.
#
# https://www.scribbr.com/statistics/p-value/

# %% [markdown]
# ***
# ### Central Limit Theorem
# CTL states that, if we collect random samples with replacement from the population, the samples will have mean μ and std dev σ, then the distribution of all the means will be normal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ###  Confidence Interval
# Confidence interval is the mean of the estimate plus or minus the variance\
# ![image.png](attachment:image.png)
# OR\
# Confidence interval is the range of values that's likely to include population value with certain degree of confidence

# %% [markdown]
# ***
# ### Null hypothesis
#
# Null hypothesis is designed assuming that there is no difference between observed values.\
# Alternate hypothesis is designed to oppose the null hypthesis
#
# The test is designed to either reject null hypothesis given the evidence or we fail to reject the null hypothesis and thus accept the hypothesis.

# %% [markdown]
# ***
# ### Type I and Type II error
#
# Type I error: false positives, when we reject null hypothesis which is true\
# telling a man you are pregnant\
# Type II error: false negatives, when we fail to reject null hypothesis\
# telling a pregnant woman she is not pregnant\
# <img src="attachment:image.png" width="300"/>
# <img src="attachment:image-2.png" width="350"/>

# %% [markdown]
# ### Confusion matrix
#
# Used to access the performace of the model.\
# \
# Different metrics are:\
# <img src=attachment:image-4.png width="450"/>
# \
# <img src=attachment:image-5.png width="400"/>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >TPR: right positives/ all positives(TP+FN)\
# FNR: wrong positives/all positives(TP+FN)\
# TNR: right negatives/all negatives(TN+FP)\
# FPR: wrong positives/all negatives(TN+FP)

# %% [markdown]
# ---
# ###  ROC and AUC
# Receiver operating characteric curve shows TPR and FPR at all thresholds and AUC is the area under the curve

# %% [markdown]
# ***
# ### Dealing with Missing Values
#
# 1. Mean imputation:null in data are replaced with corresponding mean of data. It stops us from finding features which are correlated. Also bias increases, since model cannot make assumptions for the imputed point, low variance is observed which is not correct.
#
# 2. Prediction using existing variables
#
# 3. assignment of values with Mode if majority class
#
# 4. Deleting rows if plenty of data points available in the class
#
# 5. Using random forest which support missing values??

# %% [markdown]
# ***
# ###  Dealing with Outliers
# 1. Interquartile ranges can be observed to find outliers(Min,Q1 or 25%, median or 50%, Q3 or 75%, max)
# 2. Standard deviation(how far is the data spread from mean, low std dev, data points close to mean)
# <img src=attachment:image.png width="400"/>
# <img src=attachment:image-2.png width="200"/>
#
# * Outliers are kept when they add meaning to data

# %% [markdown]
# ***
# ### Q. Sampling and handling data Imbalance
#
# Sampling: Random, Statifies, Systematic\
# <img src="https://cdn.scribbr.com/wp-content/uploads/2019/09/probability-sampling.png" width="300"/>
#
# Imbalance: Undersampling, oversampling, SMOTE
# <img src="https://miro.medium.com/max/725/1*7xf9e1EaoK5n05izIFBouA.png" width="600"/>

# %% [markdown]
# ***
# ###  Correlation
# A measure to express the strength of linear relation between two variables. It does not measure or express cause and effect
#
# > -1 means negative high correlation(one qunatity increases or decreases),\
# +1 means postive high correlation.
#
# <img src="https://miro.medium.com/max/875/1*6KNXPv-_3s7cJrcOQxbZCw.png" width="500">

# %% [markdown]
# ***
# ### Covariance

# %% [markdown]
# ***
# ### Overfitting and Underfitting
# Underfitting refers to a situation where data has high bias and low variance, while overfitting is the situation where there are high variance and low bias.
#
# >For reducing underfitting:
# >* Increase model complexity
# >* Increase the number of features
# >* Remove noise from the data
# >* Increase the number of training epochs
#
# >For reducing overfitting:
# >* Increase training data
# >* Stop early while training
# >* Lasso regularization
# >* Use random dropouts

# %% [markdown]
# ***
# ### Bias and Variance, its tradeoff
#
# Low Bias: Model makes simple, oversimplified assumptions and connot fit training data well, results in *Low Training Accuracy*.\
# High Bias: Model makes complex assumptions to fit the training data, results in *High Training Accuracy*.
# Low Variance: Model can make correct predictions on the test or unseen data, results in *High Test Accuracy*.
# High Variance: Model cannot make correct predicitons on test data or unseen data, results in *Low Test Accuracy*
#
# Bias: Error due to assumptions made on training data.Bias help us generalize better and make our model less sensitive to some single data point.Simplifying assumptions made by the model to make the target function easier to approximate.
#
# Varinace: Error due to ability to predict test data.Variance is the amount that the estimate of the target function will change given different training data.Low variance means there is a small variation in the prediction of the target function with changes in the training data set. At the same time, high variance shows a large variation in the prediction of the target

# %% [markdown]
# ***
# ### Cross-Validation

# %% [markdown]
# ***
# ### Assumption of Linear Regression
#
# 1. Linearity
# 2. Normality
# 3. Hederoscedasity

# %% [markdown]
# ***
# ### Advantages and Disadvantages of Linear Regression

# %% [markdown]
# ***
# ### Residual in LR

# %% [markdown]
# ### Q. R and R-sq

# %% [markdown]
# ### Q. SSE, SSR, SST

# %% [markdown]
# ### Q. VIF

# %% [markdown]
# ### Q. L1 and L2 regularization or Lasso and Ridge regression

# %% [markdown]
# ### Q. AIC and BIC

# %% [markdown]
# ### Q. Assumptions, Advantages and Disadavntages of Logistic Regression

# %% [markdown]
# ***
# ###  Assumptions, Advantages and Disadavntages of Decision Trees

# %% [markdown]
# ***
# ### Ensemble Learning
# ### Random Forest
# ### Boot

# %% [markdown]
# Prening, entropy, gini impurity
# Pruning a decision tree is the process of removing the sections of the tree that are not necessary or are redundant. Pruning leads to a smaller decision tree, which performs better and gives higher accuracy and speed.
#
# 18. What is entropy in a decision tree algorithm?
# In a decision tree algorithm, entropy is the measure of impurity or randomness. The entropy of a given dataset tells us how pure or impure the values of the dataset are. In simple terms, it tells us about the variance in the dataset.
# For example, suppose we are given a box with 10 blue marbles. Then, the entropy of the box is 0 as it contains marbles of the same color, i.e., there is no impurity. If we need to draw a marble from the box, the probability of it being blue will be 1.0. However, if we replace 4 of the blue marbles with 4 red marbles in the box, then the entropy increases to 0.4 for drawing blue marbles.
#
# 19. What information is gained in a decision tree algorithm?
# When building a decision tree, at each step, we have to create a node that decides which feature we should use to split data, i.e., which feature would best separate our data so that we can make predictions. This decision is made using information gain, which is a measure of how much entropy is reduced when a particular feature is used to split the data. The feature that gives the highest information gain is the one that is chosen to split the data.

# %% [markdown]
# ### Decision Tree main concepts
#
# 1. Gini Impurity:
# 2. Entropy
# 3. Information Gain
# 4. Pruning

# %% [markdown]
# ### Q. Assumptions, Advantages and Disadavntages of Random Forest

# %% [markdown]
# ### Q. Assumptions, Advantages and Disadavntages of Bagging and Boosting

# %% [markdown]
# ### Dimensionality reduction

# %% [markdown]
# Low bias: SVM, decision trees, KNN algorithm, etc.
# High bias: Linear and logistic regression

# %% [markdown]
# ### Extra Stat Questions:
# #### Normal Distribution
# 2. Unimodal: It has only one mode.
# 3. Symmetrical: Left and right halves of the curve are mirrored.
# 4. Central tendency: The mean, median, and mode are at the midpoint.
#
# #### Normal curve
# Area=1 and symmetry around zero.
#
# #### Where are long-tailed dsitribution used
# Where the tail drops off gradually towards the end of the curve
#
# #### Skewness
# Lack of symmetry around the mean or data distribution
#
# #### Kurtosis
# Exterme values present on the tail, high kurtosis, many outlier
#
# #### Bessel's correction
# Used to estimate a populations’ standard deviation from its sample. It causes the standard deviation to be less biased, thereby, providing more accurate results.
#
# #### One sample t-test
# To check if sample mean is statistically different from the population mean
#
# #### Law of large numbers
# Increase of # if trails gives results close to expected value.
# >Example: The probability of flipping a fair coin and landing heads is closer to 0.5 when it is flipped 100,000 times when compared to 100 flips.
#
# * for df>30(# of options when performing analysis) t-distribution has all characteristic of normal distribution
